# %%
import investpy

# %%
investpy.get_bonds(country='Brazil')
# Out:
#   country        name       full_name
# 0  brazil   Brazil 3M  Brazil 3-Month
# 1  brazil   Brazil 6M  Brazil 6-Month
# 2  brazil   Brazil 9M  Brazil 9-Month
# 3  brazil   Brazil 1Y   Brazil 1-Year
# 4  brazil   Brazil 2Y   Brazil 2-Year
# 5  brazil   Brazil 3Y   Brazil 3-Year
# 6  brazil   Brazil 5Y   Brazil 5-Year
# 7  brazil   Brazil 8Y   Brazil 8-Year
# 8  brazil  Brazil 10Y  Brazil 10-Year

# %%
investpy.get_certificate_countries()
# Out:
# ['france', 'germany', 'italy', 'netherlands', 'sweden']

# %%
df = investpy.get_stock_historical_data(stock='AAPL',country='United States',from_date='01/01/2010',to_date='01/01/2020')
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = investpy.get_stock_historical_data(stock='AAPL',country='United States',from_date='01/01/2010',to_date='01/01/2020')
#
# File c:\Users\lucas\workspace\github\fiap-mlet-invest-api\venv\Lib\site-packages\investpy\stocks.py:664, in get_stock_historical_data(stock, country, from_date, to_date, as_json, order, interval)
#     661 req = requests.post(url, headers=head, data=params)
#     663 if req.status_code != 200:
# --> 664     raise ConnectionError(
#     665         "ERR#0015: error " + str(req.status_code) + ", try again later."
#     666     )
#     668 if not req.text:
#     669     continue
#
# ConnectionError: ERR#0015: error 403, try again later.

# %%
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(df.head())
#
# NameError: name 'df' is not defined
